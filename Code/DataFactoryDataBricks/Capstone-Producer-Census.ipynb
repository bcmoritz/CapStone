# %%
def error_cb(err):
    """ The error callback is used for generic client errors. These
        errors are generally to be considered informational as the client will
        automatically try to recover from all errors, and no extra action
        is typically required by the application.
        For this example however, we terminate the application if the client
        is unable to connect to any broker (_ALL_BROKERS_DOWN) and on
        authentication errors (_AUTHENTICATION). """

    print("Client error: {}".format(err))
    if err.code() == KafkaError._ALL_BROKERS_DOWN or \
       err.code() == KafkaError._AUTHENTICATION:
        # Any exception raised from this callback will be re-raised from the
        # triggering flush() or poll() call.
        raise KafkaException(err)


def acked(err, msg):
    """ 
        Error callback is used for generic issues for producer errors. 
        
        Parameters:
            err (err): Error flag.
            msg (str): Error message that was part of the callback.
    """
    if err is not None:
        print("Failed to deliver message: %s: %s" % (str(msg), str(err)))
    else:
        print("Message produced: %s" % (str(msg)))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from confluent_kafka import Consumer
from time import sleep
import uuid
from confluent_kafka import Producer, Consumer, KafkaError, KafkaException
import json
from confluent_kafka.admin import AdminClient, NewTopic

confluentClusterName = "stage3talent"
confluentBootstrapServers = "pkc-ldvmy.centralus.azure.confluent.cloud:9092"
confluentTopicName = "test"
schemaRegistryUrl = "https://psrc-gq7pv.westus2.azure.confluent.cloud"
confluentApiKey = "YHMHG7E54LJA55XZ"
confluentSecret = "/XYn+w3gHGMqpe9l0TWvA9FznMYNln2STI+dytyPqtZ9QktH0TbGXUqepEsJ/nR0"
confluentRegistryApiKey = "YHMHG7E54LJA55XZ"
confluentRegistrySecret = "/XYn+w3gHGMqpe9l0TWvA9FznMYNln2STI+dytyPqtZ9QktH0TbGXUqepEsJ/nR0"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
admin_client = AdminClient({
    'bootstrap.servers': confluentBootstrapServers,
    'sasl.mechanism': 'PLAIN',
    'security.protocol': 'SASL_SSL',
    'sasl.username': confluentApiKey,
    'sasl.password': confluentSecret,
    'group.id': str(uuid.uuid1()),  # this will create a new consumer group on each invocation.
    'auto.offset.reset': 'earliest',
    'error_cb': error_cb,
})
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
topic_list = []

topic_list.append(NewTopic("cell-groupthree-census", 1, 3))
admin_client.create_topics(topic_list)
futures = admin_client.create_topics(topic_list)


try:
    record_metadata = []
    for k, future in futures.items():
        # f = i.get(timeout=10)
        print(f"type(k): {type(k)}")
        print(f"type(v): {type(future)}")
#         print(future.result())

except KafkaError:
    # Decide what to do if produce request failed...
    print(traceback.format_exc())
    result = 'Fail'
finally:
    print("finally")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from confluent_kafka import Consumer
from time import sleep
import uuid
from confluent_kafka import Producer, Consumer, KafkaError, KafkaException
import json

#KAFKA variables, Move to the OS variables or configuration
# This will work in local Jupiter Notebook, but in a databrick, hiding config.py is tougher. 
confluentClusterName = "stage3talent"
confluentBootstrapServers = "pkc-ldvmy.centralus.azure.confluent.cloud:9092"
confluentTopicName = "cell-groupthree-census"
schemaRegistryUrl = "https://psrc-gq7pv.westus2.azure.confluent.cloud"
confluentApiKey = "YHMHG7E54LJA55XZ"
confluentSecret = "/XYn+w3gHGMqpe9l0TWvA9FznMYNln2STI+dytyPqtZ9QktH0TbGXUqepEsJ/nR0"
confluentRegistryApiKey = "YHMHG7E54LJA55XZ"
confluentRegistrySecret = "/XYn+w3gHGMqpe9l0TWvA9FznMYNln2STI+dytyPqtZ9QktH0TbGXUqepEsJ/nR0"



#Kakfa Class Setup.
p = Producer({
    'bootstrap.servers': confluentBootstrapServers,
    'sasl.mechanism': 'PLAIN',
    'security.protocol': 'SASL_SSL',
    'sasl.username': confluentApiKey,
    'sasl.password': confluentSecret,
    'group.id': str(uuid.uuid1()),  # this will create a new consumer group on each invocation.
    'auto.offset.reset': 'earliest',
    'error_cb': error_cb,
})
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
###### Mount Point 1 through Oauth security.https://adb-593121260067740.0.azuredatabricks.net/?o=593121260067740#
storageAccount = "gen10dbcdatalake"
storageContainer = "group3-capstone"
clientSecret = "~bJ7Q~KslVT~sAmHkOLXL0oeTp1ZkAcndtHPr"
clientid = "2ca50102-5717-4373-b796-39d06568588d"
mount_point = "/mnt/group3"


configs = {"fs.azure.account.auth.type": "OAuth",
       "fs.azure.account.oauth.provider.type": "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider",
       "fs.azure.account.oauth2.client.id": clientid,
       "fs.azure.account.oauth2.client.secret": clientSecret,
       "fs.azure.account.oauth2.client.endpoint": "https://login.microsoftonline.com/d46b54b2-a652-420b-aa5a-2ef7f8fc706e/oauth2/token",
       "fs.azure.createRemoteFileSystemDuringInitialization": "true"}

# try: 
#     dbutils.fs.unmount(mount_point)
# except:
#     pass

# dbutils.fs.mount(
# source = "abfss://"+storageContainer+"@"+storageAccount+".dfs.core.windows.net/",
# mount_point = mount_point,
# extra_configs = configs)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df = spark.read.csv("/mnt/group3/CleanCensusData/*.csv", header = "true")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Meaning of NAICS code (NAICS2017_LABEL)</th><th>Meaning of Type of administrative expenses and benefits paid code (EXPADMBNTYPE_LABEL)</th><th>Year (YEAR)</th><th>Number of firms (FIRM)</th><th>Sales, value of shipments, or revenue ($1,000) (RCPTOT)</th><th>Administrative expenses ($1,000) (EXPADMIN)</th><th>Benefits paid ($1,000) (EXPBENP)</th></tr></thead><tbody><tr><td>Direct life insurance carriers</td><td>All types of administrative expenses and benefits paid</td><td>2017</td><td>599</td><td>501,786,132</td><td>86,658,206</td><td>268,471,706</td></tr><tr><td>Direct life insurance carriers</td><td>All types of administrative expenses and benefits paid for life insurance & annuities</td><td>2017</td><td>null</td><td>null</td><td>63,261,665</td><td>230,050,620</td></tr><tr><td>Direct life insurance carriers</td><td>All types of administrative expenses and benefits paid for life reinsurance</td><td>2017</td><td>null</td><td>null</td><td>1,992,286</td><td>1,210,875</td></tr><tr><td>Direct life insurance carriers</td><td>All types of administrative expenses and benefits paid for health insurance & hospital & medical service plans</td><td>2017</td><td>null</td><td>null</td><td>4,905,459</td><td>19,321,249</td></tr><tr><td>Direct life insurance carriers</td><td>All types of administrative expenses and benefits paid for health & medical reinsurance</td><td>2017</td><td>null</td><td>null</td><td>342,357</td><td>828,290</td></tr><tr><td>Direct life insurance carriers</td><td>All types of administrative expenses and benefits paid for accident insurance</td><td>2017</td><td>null</td><td>null</td><td>6,152,289</td><td>11,799,948</td></tr><tr><td>Direct life insurance carriers</td><td>All types of administrative expenses and benefits paid for accident reinsurance</td><td>2017</td><td>null</td><td>null</td><td>1,755,176</td><td>334,779</td></tr><tr><td>Direct life insurance carriers</td><td>All types of administrative expenses for providing claims processing and other administrative services for other parties</td><td>2017</td><td>null</td><td>null</td><td>2,587,444</td><td>null</td></tr><tr><td>Direct life insurance carriers</td><td>All types of administrative expenses and benefits paid for all other administrative expenses & benefits paid</td><td>2017</td><td>null</td><td>null</td><td>5,661,530</td><td>4,925,945</td></tr></tbody></table></div>

# %%
aDict = [row.asDict() for row in df.collect()]
print(aDict)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[{&#39;Meaning of NAICS code (NAICS2017_LABEL)&#39;: &#39;Direct life insurance carriers&#39;, &#39;Meaning of Type of administrative expenses and benefits paid code (EXPADMBNTYPE_LABEL)&#39;: &#39;All types of administrative expenses and benefits paid&#39;, &#39;Year (YEAR)&#39;: &#39;2017&#39;, &#39;Number of firms (FIRM)&#39;: &#39;599&#39;, &#39;Sales, value of shipments, or revenue ($1,000) (RCPTOT)&#39;: &#39;501,786,132&#39;, &#39;Administrative expenses ($1,000) (EXPADMIN)&#39;: &#39;86,658,206&#39;, &#39;Benefits paid ($1,000) (EXPBENP)&#39;: &#39;268,471,706&#39;}, {&#39;Meaning of NAICS code (NAICS2017_LABEL)&#39;: &#39;Direct life insurance carriers&#39;, &#39;Meaning of Type of administrative expenses and benefits paid code (EXPADMBNTYPE_LABEL)&#39;: &#39;All types of administrative expenses and benefits paid for life insurance &amp; annuities&#39;, &#39;Year (YEAR)&#39;: &#39;2017&#39;, &#39;Number of firms (FIRM)&#39;: None, &#39;Sales, value of shipments, or revenue ($1,000) (RCPTOT)&#39;: None, &#39;Administrative expenses ($1,000) (EXPADMIN)&#39;: &#39;63,261,665&#39;, &#39;Benefits paid ($1,000) (EXPBENP)&#39;: &#39;230,050,620&#39;}, {&#39;Meaning of NAICS code (NAICS2017_LABEL)&#39;: &#39;Direct life insurance carriers&#39;, &#39;Meaning of Type of administrative expenses and benefits paid code (EXPADMBNTYPE_LABEL)&#39;: &#39;All types of administrative expenses and benefits paid for life reinsurance&#39;, &#39;Year (YEAR)&#39;: &#39;2017&#39;, &#39;Number of firms (FIRM)&#39;: None, &#39;Sales, value of shipments, or revenue ($1,000) (RCPTOT)&#39;: None, &#39;Administrative expenses ($1,000) (EXPADMIN)&#39;: &#39;1,992,286&#39;, &#39;Benefits paid ($1,000) (EXPBENP)&#39;: &#39;1,210,875&#39;}, {&#39;Meaning of NAICS code (NAICS2017_LABEL)&#39;: &#39;Direct life insurance carriers&#39;, &#39;Meaning of Type of administrative expenses and benefits paid code (EXPADMBNTYPE_LABEL)&#39;: &#39;All types of administrative expenses and benefits paid for health insurance &amp; hospital &amp; medical service plans&#39;, &#39;Year (YEAR)&#39;: &#39;2017&#39;, &#39;Number of firms (FIRM)&#39;: None, &#39;Sales, value of shipments, or revenue ($1,000) (RCPTOT)&#39;: None, &#39;Administrative expenses ($1,000) (EXPADMIN)&#39;: &#39;4,905,459&#39;, &#39;Benefits paid ($1,000) (EXPBENP)&#39;: &#39;19,321,249&#39;}, {&#39;Meaning of NAICS code (NAICS2017_LABEL)&#39;: &#39;Direct life insurance carriers&#39;, &#39;Meaning of Type of administrative expenses and benefits paid code (EXPADMBNTYPE_LABEL)&#39;: &#39;All types of administrative expenses and benefits paid for health &amp; medical reinsurance&#39;, &#39;Year (YEAR)&#39;: &#39;2017&#39;, &#39;Number of firms (FIRM)&#39;: None, &#39;Sales, value of shipments, or revenue ($1,000) (RCPTOT)&#39;: None, &#39;Administrative expenses ($1,000) (EXPADMIN)&#39;: &#39;342,357&#39;, &#39;Benefits paid ($1,000) (EXPBENP)&#39;: &#39;828,290&#39;}, {&#39;Meaning of NAICS code (NAICS2017_LABEL)&#39;: &#39;Direct life insurance carriers&#39;, &#39;Meaning of Type of administrative expenses and benefits paid code (EXPADMBNTYPE_LABEL)&#39;: &#39;All types of administrative expenses and benefits paid for accident insurance&#39;, &#39;Year (YEAR)&#39;: &#39;2017&#39;, &#39;Number of firms (FIRM)&#39;: None, &#39;Sales, value of shipments, or revenue ($1,000) (RCPTOT)&#39;: None, &#39;Administrative expenses ($1,000) (EXPADMIN)&#39;: &#39;6,152,289&#39;, &#39;Benefits paid ($1,000) (EXPBENP)&#39;: &#39;11,799,948&#39;}, {&#39;Meaning of NAICS code (NAICS2017_LABEL)&#39;: &#39;Direct life insurance carriers&#39;, &#39;Meaning of Type of administrative expenses and benefits paid code (EXPADMBNTYPE_LABEL)&#39;: &#39;All types of administrative expenses and benefits paid for accident reinsurance&#39;, &#39;Year (YEAR)&#39;: &#39;2017&#39;, &#39;Number of firms (FIRM)&#39;: None, &#39;Sales, value of shipments, or revenue ($1,000) (RCPTOT)&#39;: None, &#39;Administrative e ...
# </div>

# %%
for i in aDict:
    p.produce('cell-groupthree-census', json.dumps(i))
    p.flush()
    sleep(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
